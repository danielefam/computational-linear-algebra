# %%
import pandas as pd

feature = 'Loss of interest'

columns = pd.read_csv('columns_hw.csv', header=None)
columns['question'] = columns[0].apply(lambda x: x.split(',')[0])
columns['name'] = columns[0].apply(lambda x: x.split(',')[1])
columns['name'] = columns['name'].apply(lambda x: x.strip("\""))
columns = columns.drop(columns=[0])
columns.loc[columns['name'] == feature]['question'].values[0]
# Out:
# 'I can fall for someone very quickly and then completely lose interest.'
